# %% [markdown]
# <a href="https://colab.research.google.com/github/vm00328/vm00328_coursework_com2025/blob/master/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# ...
#      |████████████████████████████████| 61kB 8.5MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-cp37-none-any.whl size=73053 sha256=7332ccaf0d07865cdf541f055fe57e7e435acaff2a2106e067a250b00de26243
#   Stored in directory: /root/.cache/pip/wheels/a1/6a/26/d30b7499ff85a4a4593377a87ecf55f7d08af42f0de9b60303
# Successfully built kaggle
# ...
#   Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6615328e-3a63-4a76-aca2-4103e110d99b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6615328e-3a63-4a76-aca2-4103e110d99b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vladislavmanolov","key":"6eb18fcccac0a8574ea1d44e4758c67e"}'}

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
! kaggle competitions download -c 'uos-com2028'
# Out:
# ...
#  98% 814M/827M [00:03<00:00, 268MB/s]
# 100% 827M/827M [00:03<00:00, 223MB/s]

# %%
! mkdir 'AI Coursework'
! unzip uos-com2028.zip -d AI_Coursework
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AI_Coursework/train/train/5499.jpg
#   inflating: AI_Coursework/train/train/55.jpg
#   inflating: AI_Coursework/train/train/550.jpg
#   inflating: AI_Coursework/train/train/5500.jpg
#   inflating: AI_Coursework/train/train/5501.jpg
#   inflating: AI_Coursework/train/train/5502.jpg
#   inflating: AI_Coursework/train/train/5503.jpg
#   inflating: AI_Coursework/train/train/5504.jpg
#   inflating: AI_Coursework/train/train/5505.jpg
#   inflating: AI_Coursework/train/train/5506.jpg
#   inflating: AI_Coursework/train/train/5507.jpg
#   inflating: AI_Coursework/train/train/5508.jpg
#   inflating: AI_Coursework/train/train/5509.jpg
#   inflating: AI_Coursework/train/train/551.jpg
#   inflating: AI_Coursework/train/train/5510.jpg
#   inflating: AI_Coursework/train/train/5511.jpg
#   inflating: AI_Coursework/train/train/5512.jpg
#   inflating: AI_Coursework/train/train/5513.jpg
#   inflating: AI_Coursework/train/train/5514.jpg
# ...

# %%
#Imports
import keras
import numpy as np
from numpy.random import seed
import tensorflow as tf
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import os
import cv2
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils
from cv2 import cv2
# %matplotlib inline

# %%
#Upload the data and make an array for the training picture
trained_pics = [None] * 10270
savedIn = 'content/cw/train/train'
for i in tqdm(os.listdir(savedIn)):
  path = os.path.join(savedIn,i)
  img = cv2.imread(path,cv2.IMREAD_COLOR)
  img = cv2.resize(img, (64,64))
  img = img/255
  i = i[:-4]
  trained_pics[int(i)] = np.array(img)
x_train = np.array(trainned_pics)

# %%
#Checking the shape
x_train.shape

# %%
#Upload the data annd make an array for the testing picture
tested_pics = [None] * 15009
savedIn = '/content/cw/test/test'
for i in tqdm(os.listdir(savedIn)):
  path = os.path.join(savedIn,i)
  img = cv2.imread(path,cv2.IMREAD_COLOR)
  img = cv2.resize(img, (64,64))
  img = img/255
  i = i[:-4]
  tested_pics[int(i)] = np.array(img)
x_test = np.array(trainned_pics)

# %%
#Check the shape of x_test
x_test.shape

# %%
#Get the Y
example = "/content/cw/train.txt"
file = open(example, "r")
lines = file.readlines()
target = []
for line in lines:
  for n in line.split()[1:]:
    target.append(int(n))
y_train = np.array(target)
print(y_train)

# %%
y_train = to_categorical(y_train)
y_train.shape

# %%
#to be done(NOT FULL)
X_train, x_test, y_train, y_test = train_test_split(x_train, y_train)

# %%
#Creating the model
def create_model(): #should i have it??
  model = Sequential()
  model.add(Conv2D(64, kernel_size=3, activation="relu",input_shape=(64,64,3)))
  model.add(Conv2D(32, kernel_size=3, activation="relu"))

  model.add(MaxPooling2D(pool_size=(3,3)))
  mode.add(Dropout(0,3))
  
  model.add(Flatten())
  model.add(Dense(23, activation="softmax"))

  return model

#model = create_model() should i have it?

#Compile the model
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
mode.summary()

#print(y_train.shape)

# %%
#Fit the model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64)

# %%
#Make the y_pred
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

print(len(y_pred))

# %%
#Creating ther .csv file
col = pd.read_csv("/content/cw/submission_sample.csv")
col["label"] = y_pred
col.to_csv("/content/code.csv", index=False)

# %%
# Ensuring replicability by other users
seed(101)
tf.random.set_seed(101)

# %%
# scale the raw pixel intensities to the range [0, 1]
#data = np.array(data, dtype="float") / 255.0

# %%
# Your code goes here
#Building the model
from keras.models import Sequential
#Adding dense layer imports
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils
model = Sequential()
#x_train, y_train, x_test = task.get_train_data()
#Hidden layers
model.add(Convolution2D(32, (2, 2), activation='relu', input_shape=(64,64,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())
#y_train = np_utils.to_categorical(trainY, 3)

#Training the model
#model.fit(X_train, y_train, epochs=10)

#Making predictions
#y_pred = model.predict(X_test)

#Visualizing the predictions
#import matplotlib.pyplot as plt
#plt.clf()
#fig = plt.figure()
#fig.suptitle('Scatter plot of Actual versus Predicted')
#plt.scatter(x=y_pred, y=y_test, marker='.')
#plt.xlabel('Predicted')
#plt.ylabel('Actual ')
#plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_18 (Conv2D)           (None, 63, 63, 32)        416
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 30, 30, 32)        4128
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               921728
# ...

# %%
#Creating a model

                    #Need to find the shape!!!

def create_model():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=3, activation="relu", input_shape=(28,28,1)))
    model.add(Conv2D(32, kernel_size=3, activation="relu"))
    model.add(Flatten())
    model.add(Dense(10, activation="softmax"))
    
    return model

# %%
#Normalization
X_train = X_train/255
X_test = X_test/255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6cb3b1792454> in <module>()
#       1 #Normalization
# ----> 2 X_train = X_train/255
#       3 X_test = X_test/255
#
# NameError: name 'X_train' is not defined

# %%
#creating new model and trainign it on the normalized set
model = create_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=4, batch_size=64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f8ba97ea4ba2> in <module>()
#       1 #creating new model and trainign it on the normalized set
# ----> 2 model = create_model()
#       3 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#       4 model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=4, batch_size=64)
#
# <ipython-input-18-fd44b2fbd551> in create_model()
#       2 def create_model():
#       3     model = Sequential()
# ----> 4     model.add(Conv2D(64, kernel_size=3, activation="relu", input_shape=(28,28,1)))
#       5     model.add(Conv2D(32, kernel_size=3, activation="relu"))
#       6     model.add(Flatten())
#
# NameError: name 'Conv2D' is not defined

# %%
#Saving the model
model.save('my_model.h5')
